# %% [markdown]
# <center>
#
# # Predictor de Tiempo de Hospitalizacion
#
# </center>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Cargar datos

# %%
# Cargar dataSet
df_healthcare = pd.read_csv('healthcare_dataset.csv')

# %%
# Convertir las columnas a tipo fecha
df_healthcare['Date of Admission'] = pd.to_datetime(df_healthcare['Date of Admission'])
df_healthcare['Discharge Date'] = pd.to_datetime(df_healthcare['Discharge Date'])

# Crear la variable objetivo (duración en días)
df_healthcare['Length of Stay'] = (df_healthcare['Discharge Date'] - df_healthcare['Date of Admission']).dt.days

# Cargar de las primeras 5 columnas del archivo
df_healthcare.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# 0    18856.281306          328         Urgent     2024-02-02  Paracetamol
# 1    33643.327287          265      Emergency     2019-08-26    Ibuprofen
# 2    27955.096079          205      Emergency     2022-10-07      Aspirin
# 3    37909.782410          450       Elective     2020-12-18    Ibuprofen
# 4    14238.317814          458         Urgent     2022-10-09   Penicillin
#
#    Test Results  Length of Stay
# 0        Normal               2
# 1  Inconclusive               6
# 2        Normal              15
# 3      Abnormal              30
# 4      Abnormal              20

# %% [markdown]
# ## Preparar conjuntos de entrenamientos y pruebas

# %%
# Categorizar el campo income_cat para estratificar los sets de training y test
df_healthcare["age_cat"] = pd.cut(df_healthcare["Age"],
                                    bins=[0,18,35,50,65,np.inf],
                                    labels=[1, 2, 3, 4, 5])

# %%
# Generando los dataSets estratificados
 
from sklearn.model_selection import train_test_split
 
strat_train_set, strat_test_set = train_test_split(df_healthcare, 
                                                   test_size=0.2, 
                                                   stratify=df_healthcare["age_cat"], 
                                                   random_state=42)
 
print('Tamaño del train_set',strat_train_set.shape)
print('Tamaño del test_set',strat_test_set.shape)
# Out:
# Tamaño del train_set (44400, 17)
# Tamaño del test_set (11100, 17)

# %%
# Prepara el dataSet de training
# Separar los atributos de la variable objetivo
 
dfDistTrain = strat_train_set.drop("Length of Stay", axis=1)
dfDistTrain.drop('age_cat', axis=1, inplace=True)
dfDistTrain_labels = strat_train_set["Length of Stay"].copy()
 
print(dfDistTrain.shape)
print(dfDistTrain_labels.shape)
# Out:
# (44400, 15)
# (44400,)

# %%
import numpy as np

# Copia del conjunto predictivo (para no alterar el original)
dfDistTrain_nulos = dfDistTrain.copy()

# Cantidad de valores nulos a insertar
n = 800
np.random.seed(42)

# Columnas donde insertar nulos (algunas numéricas y categóricas)
columnas_con_nulos = ['Billing Amount', 'Medication', 'Test Results']

for col in columnas_con_nulos:
    idx = np.random.choice(dfDistTrain_nulos.index, n, replace=False)
    dfDistTrain_nulos.loc[idx, col] = np.nan

# Confirmar cuántos nulos hay
dfDistTrain_nulos.isnull().sum()
# Out:
# Name                    0
# Age                     0
# Gender                  0
# Blood Type              0
# Medical Condition       0
# Date of Admission       0
# Doctor                  0
# Hospital                0
# Insurance Provider      0
# Billing Amount        800
# Room Number             0
# Admission Type          0
# Discharge Date          0
# Medication            800
# Test Results          800
# dtype: int64

# %%
# IMPUTACIÓN DE VALORES NULOS (adaptado al dataset actual)

from sklearn.impute import SimpleImputer
import numpy as np

# Se copia el DataFrame con nulos
dfDistTrain_imputado = dfDistTrain_nulos.copy()

# Imputación para variables numéricas (usando la mediana)
imputer_median = SimpleImputer(strategy='median')

# Seleccionamos solo las numéricas
num_cols = dfDistTrain_imputado.select_dtypes(include=[np.number]).columns

# Aplicamos el imputador
dfDistTrain_imputado[num_cols] = imputer_median.fit_transform(dfDistTrain_imputado[num_cols])

# Imputación para variables categóricas (usando la moda)
imputer_mode = SimpleImputer(strategy='most_frequent')

# Seleccionamos las categóricas
cat_cols = dfDistTrain_imputado.select_dtypes(exclude=[np.number]).columns

# Aplicamos el imputador
dfDistTrain_imputado[cat_cols] = imputer_mode.fit_transform(dfDistTrain_imputado[cat_cols])

# Verificamos que no haya nulos
dfDistTrain_imputado.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %% [markdown]
# ## Preparar transformadores y pipelines para procesamiento

# %%
# Bibliotecas para crear el transformador de clusters
 
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.metrics.pairwise import rbf_kernel
from sklearn.cluster import KMeans

# %%
class ClusterSimilarity(BaseEstimator, TransformerMixin):
    def __init__(self, n_clusters=10, gamma=1.0, random_state=None):
        self.n_clusters = n_clusters
        self.gamma = gamma
        self.random_state = random_state
 
    def fit(self, X, y=None, sample_weight=None):
        self.kmeans_ = KMeans(self.n_clusters, n_init=10,
                              random_state=self.random_state)
        self.kmeans_.fit(X, sample_weight=sample_weight)
        return self  
 
    def transform(self, X):
        return rbf_kernel(X, self.kmeans_.cluster_centers_, gamma=self.gamma)
    def get_feature_names_out(self, names=None):
        return [f"Cluster {i} similarity" for i in range(self.n_clusters)]

# %%
from sklearn.preprocessing import OneHotEncoder, StandardScaler, FunctionTransformer
from sklearn.compose import ColumnTransformer
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.preprocessing import FunctionTransformer, StandardScaler
from sklearn.compose import make_column_selector

# %%
# Hacemos una copia del dataset imputado
dfTrain_final = dfDistTrain_imputado.copy()

# Aseguramos que las fechas estén en formato datetime
dfTrain_final["Date of Admission"] = pd.to_datetime(dfTrain_final["Date of Admission"])
dfTrain_final["Discharge Date"] = pd.to_datetime(dfTrain_final["Discharge Date"])

# Creamos la variable objetivo (no se queda en X)
dfTrain_final["Length of Stay"] = (
    dfTrain_final["Discharge Date"] - dfTrain_final["Date of Admission"]
).dt.days

# Definimos la variable objetivo
y = dfTrain_final["Length of Stay"].copy()

# Columnas que NO queremos usar como predictoras
cols_to_drop = [
    "Name",
    "Date of Admission",
    "Discharge Date",
    "Doctor",
    "Hospital",
    "Length of Stay"
]

# Creamos X sin la variable objetivo ni columnas irrelevantes
X = dfTrain_final.drop(columns=cols_to_drop)

print("Columnas en X:", X.columns.tolist())
print("Variable objetivo (y):", y.name)
# Out:
# Columnas en X: ['Age', 'Gender', 'Blood Type', 'Medical Condition', 'Insurance Provider', 'Billing Amount', 'Room Number', 'Admission Type', 'Medication', 'Test Results']
# Variable objetivo (y): Length of Stay

# %%
# Función para calcular las columnas nuevas (ratios)
def column_ratio(X):
    X = np.asarray(X, dtype=float)
    numerador = X[:, [0]]      # Billing Amount
    denominador = X[:, [1]]    # Length of Stay

    # Evitar división entre 0 o valores negativos
    denominador_seguro = np.where(denominador <= 0, 1e-6, denominador)

    return numerador / denominador_seguro
 
# Función para asignar los nombres de las nuevas columnas (ratios)
def ratio_name(function_transformer, feature_names_in):
    return ["ratio"]  # feature names out
 
# Pipeline para imputar las columnas sobre las que se basarán los ratios, luego genera los ratios 
# y finalmente estandariza los resultados
def ratio_pipeline():
    return make_pipeline(SimpleImputer(strategy="median"),
                         FunctionTransformer(column_ratio, feature_names_out=ratio_name),
                         StandardScaler())

def safe_log(X):
    X = np.asarray(X, dtype=float)
    # mínimo por columna
    mins = np.nanmin(X, axis=0)
    # para columnas con min <= 0, calculamos cuánto hay que sumar para hacerlas positivas
    offsets = np.where(mins <= 0, -mins + 1e-6, 0.0)
    X_shifted = X + offsets   # se suma por columna
    return np.log(X_shifted)


# Pipeline para imputar, aplicar una transformación logarítmica y estandarizar los resultados 
log_pipeline = make_pipeline(SimpleImputer(strategy="median"),
                             FunctionTransformer(safe_log, feature_names_out="one-to-one"),
                             StandardScaler())
 
# Función para calcular las similitudes con los 10 clusters
cluster_simil = ClusterSimilarity(n_clusters=10, gamma=1., random_state=42)
 
# Pipeline para imputar y estandarizar
default_num_pipeline = make_pipeline(SimpleImputer(strategy="median"),
                                     StandardScaler())

# Lista explícita de categóricas que SÍ queremos usar
cat_features = [
    "Gender",
    "Blood Type",
    "Medical Condition",
    "Insurance Provider",
    "Admission Type",
    "Medication",
    "Test Results"
]

# Pipeline: imputa y codfica categorías
cat_pipeline = make_pipeline(SimpleImputer(strategy="most_frequent"),
                             OneHotEncoder(handle_unknown="ignore"))
 
# Integra los pipelines
preprocessing = ColumnTransformer([("billing_per_age", ratio_pipeline(), ["Billing Amount", "Age"]),                                   
                                   ("log", log_pipeline, ["Billing Amount", "Age"]),
                                   ("cat", cat_pipeline, cat_features),
                                   ("num_rest", default_num_pipeline, ["Room Number"]),
                                  ],
                                  remainder="drop")  # evita que fechas caigan al pipeline numérico

# %%
# Aplica 
X_preproc = preprocessing.fit_transform(X)
print(type(X_preproc))
print("Shape transformada:", X_preproc.shape)
print("Cantidad de columnas resultantes:", len(preprocessing.get_feature_names_out()))
# Out:
# <class 'numpy.ndarray'>
# Shape transformada: (44400, 36)
# Cantidad de columnas resultantes: 36

# %%
from pandas import DataFrame

dfDistTrainProc = pd.DataFrame(
    X_preproc,
    columns=preprocessing.get_feature_names_out(),
    index=X.index
)

dfDistTrainProc.head(2)
# Out:
#        billing_per_age__ratio  log__Billing Amount  log__Age  \
# 40666                0.439625             1.145786  0.588217
# 48983               -1.150262            -1.862861  0.840192
#
#        cat__Gender_Female  cat__Gender_Male  cat__Blood Type_A+  \
# 40666                 1.0               0.0                 1.0
# 48983                 1.0               0.0                 0.0
#
#        cat__Blood Type_A-  cat__Blood Type_AB+  cat__Blood Type_AB-  \
# 40666                 0.0                  0.0                  0.0
# 48983                 0.0                  0.0                  0.0
#
#        cat__Blood Type_B+  ...  cat__Admission Type_Urgent  \
# 40666                 0.0  ...                         0.0
# 48983                 0.0  ...                         0.0
#
#        cat__Medication_Aspirin  cat__Medication_Ibuprofen  \
# 40666                      0.0                        1.0
# 48983                      0.0                        0.0
#
#        cat__Medication_Lipitor  cat__Medication_Paracetamol  \
# 40666                      0.0                          0.0
# 48983                      1.0                          0.0
#
#        cat__Medication_Penicillin  cat__Test Results_Abnormal  \
# 40666                         0.0                         0.0
# 48983                         0.0                         0.0
#
#        cat__Test Results_Inconclusive  cat__Test Results_Normal  \
# 40666                             1.0                       0.0
# 48983                             1.0                       0.0
#
#        num_rest__Room Number
# 40666               1.471719
# 48983              -1.519785
#
# [2 rows x 36 columns]

# %% [markdown]
# ## Entrenamiento de varios modelos y selección

# %% [markdown]
# ### Regresión Lineal

# %%
# Regresión Lineal

from sklearn import set_config
set_config(display='diagram')

from sklearn.model_selection import cross_val_score

# Seleccionar una Regresión Lineal
from sklearn.linear_model import LinearRegression

# Definir el pipeline de preprocesamiento y entrenamiento
lin_reg = make_pipeline(preprocessing, LinearRegression())

# Realizar 10 entrenamientos cambiando cada vez el fold de pruebas, 3 minutos aproximadamente.
lin_rmses = -cross_val_score(
    lin_reg,
    X,
    y,
    scoring="neg_root_mean_squared_error",
    cv=10
)

# Calcular estadísticas
pd.Series(lin_rmses).describe()
# Out:
# count    10.000000
# mean      8.668057
# std       0.064727
# min       8.568779
# 25%       8.622133
# 50%       8.669505
# 75%       8.701840
# max       8.761051
# dtype: float64

# %% [markdown]
# ### Árbol de Decisión

# %%
from sklearn import set_config
set_config(display='diagram')

from sklearn.model_selection import cross_val_score

# Seleccionar un Árbol de Decisión
from sklearn.tree import DecisionTreeRegressor

# Definir el pipeline de preprocesamiento y entrenamiento
tree_reg = make_pipeline(
    preprocessing,
    DecisionTreeRegressor(random_state=42)
)

# Realizar 10 entrenamientos cambiando cada vez el fold de pruebas
tree_rmses = -cross_val_score(
    tree_reg,
    X,
    y,
    scoring="neg_root_mean_squared_error",
    cv=10       # 10 particiones exactamente igual al ejemplo
)

# Calcular estadísticas
pd.Series(tree_rmses).describe()
# Out:
# count    10.000000
# mean     11.970851
# std       0.133621
# min      11.735246
# 25%      11.906385
# 50%      11.946413
# 75%      12.024972
# max      12.221676
# dtype: float64

# %% [markdown]
# ### Bosque Aleatorio

# %%
from sklearn import set_config
set_config(display='diagram')

from sklearn.model_selection import cross_val_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.pipeline import make_pipeline

# Seleccionar un Bosque Aleatorio
forest_reg = make_pipeline(
    preprocessing,
    RandomForestRegressor(
        n_estimators=200,     # suficientes árboles
        max_depth=12,        # evita árboles gigantes
        n_jobs=-1,           # usa todos los núcleos del CPU
        random_state=42
    )
)

# Realizar 10 entrenamientos cambiando cada vez el fold de pruebas, 3 minutos aproximadamente.
forest_rmses = -cross_val_score(
    forest_reg,
    X,
    y,
    scoring="neg_root_mean_squared_error",
    cv=10
)

# Calcular estadísticas
pd.Series(forest_rmses).describe()
# Out:
# count    10.000000
# mean      8.643646
# std       0.065682
# min       8.546755
# 25%       8.594755
# 50%       8.648421
# 75%       8.675777
# max       8.736875
# dtype: float64

# %% [markdown]
# ## Afinar modelo seleccionado

# %% [markdown]
# Se afinará el modelo de Bosque Aleatorio dado que tuvo el mejor rendimiento.
# [Bosque Aleatorio](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html)

# %% [markdown]
# ### Usando Grid Search

# %% [markdown]
# Se decidió usar **Grid Search** en lugar de Randomized Search porque en este proyecto los hiperparámetros del Bosque Aleatorio son pocos y tienen rangos pequeños y controlados. Esto hace que Grid Search pueda probar todas las combinaciones posibles de manera rápida y encontrar la mejor con precisión. En cambio, Randomized Search tardó más tiempo y generó modelos más pesados sin mejorar realmente el rendimiento.

# %%
from sklearn.model_selection import GridSearchCV
 
# Definir pipeline de preprocesamiento y entrenamiento
full_pipeline = Pipeline([
    ("preprocessing", preprocessing),
    ("random_forest", RandomForestRegressor(random_state=42)) #algoritmo de entrenamiento
])
 
# Grid de valores para hiperparámetros (una lista / matriz)
# Diccionarios con configuraciones
param_grid = {
    "random_forest__n_estimators": [100, 200],
    "random_forest__max_depth": [8, 12, 16],
    "random_forest__max_features": ["sqrt", "log2"],
    "random_forest__min_samples_split": [2, 5],
    "random_forest__min_samples_leaf": [1, 2]
}
 
# Definir el Grid de búsqueda con cross-validation de 3 folds
grid_search = GridSearchCV(
    full_pipeline,
    param_grid,
    cv=3,
    scoring="neg_root_mean_squared_error",
    n_jobs=-1
)

# %%
import time
 
inicio = time.time()
grid_search.fit(X, y)
fin = time.time()
(fin - inicio) / 60  # Más de 3 minutos aproximadamente
# Out:
# 6.276461640993754

# %%
# Resultados del grid en visualización más amigable
 
cv_res = pd.DataFrame(grid_search.cv_results_)
cv_res.sort_values(by="mean_test_score", ascending=False, inplace=True)
 
cv_res[:5]
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 41      32.439449      2.925726         1.818588        0.364681
# 33      34.576243      3.288420         1.572925        0.162935
# 40      14.710083      1.381528         0.813188        0.067849
# 32      17.589273      2.626216         0.824169        0.126020
# 43      24.868366      0.692700         1.430864        0.155479
#
#     param_random_forest__max_depth param_random_forest__max_features  \
# 41                              16                              log2
# 33                              16                              sqrt
# 40                              16                              log2
# 32                              16                              sqrt
# 43                              16                              log2
#
#     param_random_forest__min_samples_leaf  \
# 41                                      1
# 33                                      1
# 40                                      1
# 32                                      1
# 43                                      1
#
#     param_random_forest__min_samples_split  param_random_forest__n_estimators  \
# 41                                       2                                200
# 33                                       2                                200
# 40                                       2                                100
# 32                                       2                                100
# 43                                       5                                200
#
#                                                params  split0_test_score  \
# 41  {'random_forest__max_depth': 16, 'random_fores...          -8.587079
# 33  {'random_forest__max_depth': 16, 'random_fores...          -8.596412
# 40  {'random_forest__max_depth': 16, 'random_fores...          -8.600454
# 32  {'random_forest__max_depth': 16, 'random_fores...          -8.600828
# 43  {'random_forest__max_depth': 16, 'random_fores...          -8.612581
#
#     split1_test_score  split2_test_score  mean_test_score  std_test_score  \
# 41          -8.533307          -8.551132        -8.557173        0.022364
# 33          -8.544956          -8.559146        -8.566838        0.021699
# 40          -8.541386          -8.560816        -8.567552        0.024580
# 32          -8.552542          -8.569917        -8.574429        0.019969
# 43          -8.551728          -8.567656        -8.577322        0.025766
#
#     rank_test_score
# 41                1
# 33                2
# 40                3
# 32                4
# 43                5

# %% [markdown]
# #### El mejor modelo es el de la primera fila (rank 1) porque tiene el mean_test_score menos negativo, lo que significa que tuvo el menor error (RMSE) en las pruebas.
#
# - Cometió el menor error promedio al predecir los días de hospitalización.
# - Usó la combinación de hiperparámetros que mejor funcionó:
#
# max_depth = 16 /
# max_features = "log2" /
# min_samples_leaf = 1 /
# min_samples_split = 2 /
# n_estimators = 200
#
# Esto indica que este modelo aprendió mejor los patrones del dataset sin sobreajustar y con buena estabilidad.

# %%
# Solo resultados del rendimiento
 
cv_res = cv_res[[
    "param_random_forest__max_depth",
    "param_random_forest__max_features",
    "param_random_forest__n_estimators",
    "split0_test_score",
    "split1_test_score",
    "split2_test_score",
    "mean_test_score"
]]
 
score_cols = ["split0", "split1", "split2", "mean_test_rmse"]
 
cv_res.columns = [
    "max_depth",
    "max_features",
    "n_estimators"
] + score_cols

 
cv_res[score_cols] = -cv_res[score_cols]
 
cv_res.head()
# Out:
#     max_depth max_features  n_estimators    split0    split1    split2  \
# 41         16         log2           200  8.587079  8.533307  8.551132
# 33         16         sqrt           200  8.596412  8.544956  8.559146
# 40         16         log2           100  8.600454  8.541386  8.560816
# 32         16         sqrt           100  8.600828  8.552542  8.569917
# 43         16         log2           200  8.612581  8.551728  8.567656
#
#     mean_test_rmse
# 41        8.557173
# 33        8.566838
# 40        8.567552
# 32        8.574429
# 43        8.577322

# %%
# Mejor modelo

final_model = grid_search.best_estimator_
final_model
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(transformers=[('billing_per_age',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('functiontransformer',
#                                                                    FunctionTransformer(feature_names_out=<function ratio_name at 0x000001D945D1C540>,
#                                                                                        func=<function column_ratio at 0x000001D945D1C4A0>)),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['Billing...
#                                                   ['Gender', 'Blood Type',
#                                                    'Medical Condition',
#                                                    'Insurance Provider',
#                                                    'Admission Type',
#                                                    'Medication',
#                                                    'Test Results']),
#                                                  ('num_rest',
#                                                   Pipeline(steps=[('simpleimputer',
#                                                                    SimpleImputer(strategy='median')),
#                                                                   ('standardscaler',
#                                                                    StandardScaler())]),
#                                                   ['Room Number'])])),
#                 ('random_forest',
#                  RandomForestRegressor(max_depth=16, max_features='log2',
#                                        n_estimators=200, random_state=42))])

# %% [markdown]
# El pipeline primero limpia y transforma tus columnas según su tipo, y luego entrena un Random Forest optimizado que usa 200 árboles y profundidad 16 para predecir la duración de la hospitalización.

# %% [markdown]
# ### Evaluar el modelo con el "test set"

# %%
from sklearn.metrics import root_mean_squared_error

# Separar X_test y y_test
X_test = strat_test_set.drop("Length of Stay", axis=1)
y_test = strat_test_set["Length of Stay"].copy()

# Predicciones del mejor modelo
final_predictions = final_model.predict(X_test)

# RMSE final
final_rmse = root_mean_squared_error(y_test, final_predictions)

print(final_rmse)
# Out:
# 8.478550558878851

# %%
from scipy import stats

confidence = 0.95

squared_errors = (final_predictions - y_test) ** 2

np.sqrt(
    stats.t.interval(
        confidence,
        len(squared_errors) - 1,
        loc=squared_errors.mean(),
        scale=stats.sem(squared_errors)
    )
)
# Out:
# array([8.4058784, 8.5506051])

# %% [markdown]
# ### Revisar importancia de atributos

# %%
sorted(
    zip(final_model["random_forest"].feature_importances_,final_model["preprocessing"].get_feature_names_out()),
    reverse=True
)
# Out:
# [(np.float64(0.15078832838556577), 'log__Billing Amount'),
#  (np.float64(0.1468200031912715), 'num_rest__Room Number'),
#  (np.float64(0.14637187263109944), 'billing_per_age__ratio'),
#  (np.float64(0.12517310245429872), 'log__Age'),
#  (np.float64(0.016549907035574126), 'cat__Test Results_Normal'),
#  (np.float64(0.01637661245305135), 'cat__Test Results_Abnormal'),
#  (np.float64(0.016338314385078084), 'cat__Test Results_Inconclusive'),
#  (np.float64(0.016224891576960016), 'cat__Gender_Female'),
#  (np.float64(0.016012765858436313), 'cat__Gender_Male'),
#  (np.float64(0.01548777345559838), 'cat__Admission Type_Elective'),
#  (np.float64(0.01505619338845043), 'cat__Insurance Provider_Medicare'),
#  (np.float64(0.014877918910266965), 'cat__Admission Type_Emergency'),
#  (np.float64(0.01467905113242867), 'cat__Insurance Provider_Cigna'),
#  (np.float64(0.014370406942552027), 'cat__Insurance Provider_Aetna'),
#  (np.float64(0.014313289363601517), 'cat__Insurance Provider_Blue Cross'),
#  (np.float64(0.014213852423770353), 'cat__Medication_Aspirin'),
#  (np.float64(0.014213096902696584),
#   'cat__Insurance Provider_UnitedHealthcare'),
#  (np.float64(0.01402099401149714), 'cat__Medication_Lipitor'),
#  (np.float64(0.013960863488296862), 'cat__Medication_Penicillin'),
#  (np.float64(0.013919580181863069), 'cat__Medication_Paracetamol'),
#  (np.float64(0.013897746133728087), 'cat__Admission Type_Urgent'),
#  (np.float64(0.013538755839244004), 'cat__Medication_Ibuprofen'),
#  (np.float64(0.01310207812804674), 'cat__Medical Condition_Cancer'),
#  (np.float64(0.012940323540791035), 'cat__Medical Condition_Diabetes'),
#  (np.float64(0.012912738413413184), 'cat__Medical Condition_Hypertension'),
#  (np.float64(0.012845185161017316), 'cat__Medical Condition_Obesity'),
#  (np.float64(0.012752242657411693), 'cat__Medical Condition_Arthritis'),
#  (np.float64(0.012009707504186057), 'cat__Medical Condition_Asthma'),
#  (np.float64(0.01119674950038217), 'cat__Blood Type_A+'),
#  (np.float64(0.010878341900124164), 'cat__Blood Type_O-'),
#  (np.float64(0.010860206829737389), 'cat__Blood Type_B-'),
#  (np.float64(0.01085912529562422), 'cat__Blood Type_B+'),
#  (np.float64(0.010775396273447648), 'cat__Blood Type_AB-'),
#  (np.float64(0.010617628289480707), 'cat__Blood Type_AB+'),
#  (np.float64(0.010566487419160978), 'cat__Blood Type_O+'),
#  (np.float64(0.010478468941847433), 'cat__Blood Type_A-')]
